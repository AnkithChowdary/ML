# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df=pd.read_csv("prices_area.csv")
df
# Out:
#     Area    Price
# 0   3974  1219588
# 1   1660   550688
# 2   2094   689842
# 3   1930   646754
# 4   1895   636386
# ..   ...      ...
# 95  1876   595089
# 96  1591   520165
# 97  3064   980322
# 98  1563   539777
# 99  3035   971028
#
# [100 rows x 2 columns]

# %%
# %matplotlib inline
plt.xlabel('Area(sqr ft)')
plt.ylabel('Price(INR)')
plt.scatter(df["Area"],df["Price"],color='red',marker='+')

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['Area']],df.Price)
# Out:
# LinearRegression()

# %%
reg.predict([[3300]])
# Out:
# c:\Users\Ankith\Desktop\ML\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([1041397.78880988])

# %%
reg.coef_
# Out:
# array([300.692217])

# %%
reg.intercept_
# Out:
# np.float64(49113.47272143897)

# %%
300.692217*3300+49113.47272143897
# Out:
# 1041397.788821439

# %%
# %matplotlib inline
plt.xlabel('Area',fontsize=20)
plt.ylabel('Price',fontsize=20)
plt.scatter(df.Area,df.Price,color='red',marker='+')
plt.plot(df.Area,reg.predict(df[['Area']]),color='blue')

# %%
d=pd.read_csv("areas.csv")
d.head(3)
# Out:
#    Area
# 0  3974
# 1  1660
# 2  2094

# %%
prices=reg.predict(d)

# %%
d['Prices']=prices

# %%
d.to_csv("prediction.csv",index=False)

# %%
dd=pd.read_csv("canada_per_capita_income.csv")
dd
# Out:
#     year        income
# 0   1970   3399.299037
# 1   1971   3768.297935
# 2   1972   4251.175484
# 3   1973   4804.463248
# 4   1974   5576.514583
# 5   1975   5998.144346
# 6   1976   7062.131392
# 7   1977   7100.126170
# 8   1978   7247.967035
# 9   1979   7602.912681
# 10  1980   8355.968120
# 11  1981   9434.390652
# 12  1982   9619.438377
# 13  1983  10416.536590
# 14  1984  10790.328720
# 15  1985  11018.955850
# 16  1986  11482.891530
# 17  1987  12974.806620
# 18  1988  15080.283450
# 19  1989  16426.725480
# 20  1990  16838.673200
# 21  1991  17266.097690
# 22  1992  16412.083090
# 23  1993  15875.586730
# 24  1994  15755.820270
# 25  1995  16369.317250
# 26  1996  16699.826680
# 27  1997  17310.757750
# 28  1998  16622.671870
# 29  1999  17581.024140
# 30  2000  18987.382410
# 31  2001  18601.397240
# 32  2002  19232.175560
# 33  2003  22739.426280
# 34  2004  25719.147150
# 35  2005  29198.055690
# 36  2006  32738.262900
# 37  2007  36144.481220
# 38  2008  37446.486090
# ...

# %%
myReg=linear_model.LinearRegression()
myReg.fit(dd[['year']],dd.income)
# Out:
# LinearRegression()

# %%
newDf=pd.read_csv("years_2020_2027.csv")
newDf
# Out:
#    year
# 0  2020
# 1  2021
# 2  2022
# 3  2023
# 4  2024
# 5  2025
# 6  2026
# 7  2027

# %%
predictedIncome=myReg.predict(newDf)

# %%
newDf['predictedIncome']=predictedIncome
newDf.to_csv("newPredictedIncomes.csv")
