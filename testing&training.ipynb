# %%
import pandas as pd
df=pd.read_csv("car_data.csv")
df
# Out:
#    Mileage  Age  Sell_Price
# 0    15000    2      450000
# 1    25000    3      400000
# 2    12000    1      470000
# 3    30000    4      370000
# 4    10000    1      490000
# 5    22000    3      410000
# 6    18000    2      430000
# 7    35000    5      340000
# 8    27000    4      360000
# 9    14000    2      460000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(df['Mileage'],df['Sell_Price'])

# %%
plt.scatter(df['Age'],df['Sell_Price'])

# %%
x=df[['Mileage','Age']]
y=df['Sell_Price']
x
# Out:
#    Mileage  Age
# 0    15000    2
# 1    25000    3
# 2    12000    1
# 3    30000    4
# 4    10000    1
# 5    22000    3
# 6    18000    2
# 7    35000    5
# 8    27000    4
# 9    14000    2

# %%
y
# Out:
# 0    450000
# 1    400000
# 2    470000
# 3    370000
# 4    490000
# 5    410000
# 6    430000
# 7    340000
# 8    360000
# 9    460000
# Name: Sell_Price, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
# 20% for testing and 80% for training the data
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x_train
# Out:
#    Mileage  Age
# 9    14000    2
# 3    30000    4
# 6    18000    2
# 2    12000    1
# 4    10000    1
# 1    25000    3
# 8    27000    4
# 0    15000    2

# %%
from sklearn.linear_model import LinearRegression
clf=LinearRegression()

# %%
clf.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
clf.predict(x_test)
# Out:
# array([325788.91257996, 406934.96801706])

# %%
y_test
# Out:
# 7    340000
# 5    410000
# Name: Sell_Price, dtype: int64

# %%
clf.score(x_test,y_test)
# Out:
# 0.9137349278707955
